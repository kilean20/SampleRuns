# %%
import numpy as np
import matplotlib.pyplot as plt
from copy import deepcopy as copy

# %%
NL_c = 0.01
EmitStr = ['7','14','28']
nEmit = len(EmitStr)
Emit  = [float(emit)*1.0e-9/NL_c**2 for emit in EmitStr]
tunex = 0.85386582
_x = 2
_xSTR = 'Y'
q_max = 20.0
k_max = 0.1
dw_dI = -2*np.pi*0.65303641

# %%
def GaussDist(x):
    return np.exp(-x**2/2.0)/np.sqrt(2.0*np.pi)
Q = np.linspace(-q_max,q_max,2048)
histData = GaussDist(Q)
dq = Q[1]-Q[0]

# %% [markdown]
# # Centroid from tracking

# %%
cData=[]
pData=[]
Xi0  =[]
nMax =[]
i=0
for i in range(nEmit):
    cData.append(np.real(np.load(_xSTR+'.ent.emit'+EmitStr[i]+'nm.npy'))) 
    pData.append(np.imag(np.load(_xSTR+'.ent.emit'+EmitStr[i]+'nm.npy')))

# %%
legend = [emit + ' nm' for emit in EmitStr]
plt.figure(figsize=(12,3))
plt.subplot(1,3,1)
for i in range(len(Emit)):
    plt.plot(cData[i][:int(16/np.sqrt(Emit[i]))])
plt.legend(legend)
plt.subplot(1,3,2)
for i in range(len(Emit)):
    plt.plot(cData[i][:10])
plt.legend(legend)
plt.subplot(1,3,3)
for i in range(len(Emit)):
    plt.plot(pData[i][:10])
plt.legend(legend)

for i in range(len(Emit)):
    iMin=np.argmin(np.abs(pData[i][:16]))
    Xi0.append(cData[i][iMin])
    print(iMin,Xi0[i])
    print(Xi0[i])
    cData[i]=cData[i][iMin:]/cData[i][iMin]
    cData[i]=cData[i][:int(16/np.sqrt(Emit[i]))]
# Out:
# 15 0.2198257305087604
# 0.2198257305087604
# 15 0.21811464574642642
# 0.21811464574642642
# 15 0.21451249172819573
# 0.21451249172819573

# %%
plt.figure(figsize=(12,3))
plt.subplot(1,3,1)
for i in range(len(Emit)):
    plt.plot(cData[i])
plt.legend(legend)
plt.subplot(1,3,2)
for i in range(len(Emit)):
    plt.plot(cData[i][:10])
plt.legend(legend)
plt.subplot(1,3,3)
for i in range(len(Emit)):
    plt.plot(pData[i][:10])
plt.legend(legend)

# %% [markdown]
# # Compare cData Time Domain

# %% [markdown]
# ### as it is

# %%
cDataModel = [0]*nEmit
for i in range(nEmit):
    T = len(cData[i])
    cDataModel[i]=np.zeros(T,dtype=np.complex)
    for t in range(T):
        cDataModel[i][t] = np.sum(histData*np.exp(-1j*t*Emit[i]**0.5*Q*Xi0[i]*dw_dI)*dq)*np.exp(-2j*np.pi*tunex*t)    
    cDataModel[i] = cDataModel[i]/cDataModel[i][0]

# %%
plt.figure(figsize=(nEmit*4,3))
for i in range(nEmit):
    plt.subplot(1,nEmit,i+1)
    plt.plot(np.abs(cDataModel[i]),alpha=0.8)
    plt.plot(np.abs(cData[i]),     alpha=0.8)

# %% [markdown]
# ### artificial fitting <--- 1.35 factor

# %%
cDataModel = [0]*nEmit
for i in range(nEmit):
    T = len(cData[i])
    cDataModel[i]=np.zeros(T,dtype=np.complex)
    for t in range(T):
        cDataModel[i][t] = np.sum(histData*np.exp(-1.35j*t*Emit[i]**0.5*Q*Xi0[i]*dw_dI)*dq)*np.exp(-2j*np.pi*tunex*t)    
    cDataModel[i] = cDataModel[i]/cDataModel[i][0]

# %%
plt.figure(figsize=(nEmit*4,3))
for i in range(nEmit):
    plt.subplot(1,nEmit,i+1)
    plt.plot(np.abs(cDataModel[i]),alpha=0.8)
    plt.plot(np.abs(cData[i]),     alpha=0.8)

# %% [markdown]
# # Compare cData Freq Domain

# %%
nSample = 2048
K = np.linspace(-k_max,k_max,nSample)
Tune = [0]*len(Emit)
Amp  = [0]*len(Emit)
for i in range(len(Emit)):
    T = len(cData[i])
    Amp[i] = np.zeros(nSample,dtype=np.complex)
    Tune[i] = tunex + K
    for k in range(nSample):
        Amp[i][k] = np.sum(cData[i]*np.exp(2j*np.pi*Tune[i][k]*np.arange(0,T)))
    Amp[i] = Amp[i]*Emit[i]**0.5*2

# %%
Q = Q
histData = histData*np.pi/np.abs(Xi0[0]*dw_dI)

# %% [markdown]
# ### as it is

# %%
from scipy.signal import hilbert
plt.figure(figsize=(12,4))

plt.subplot(1,2,1)
for i in range(len(Emit)):
    plt.plot(2*np.pi*K/(Emit[i]**0.5*Xi0[i]*dw_dI),np.real(Amp[i]))
plt.plot(Q,histData,color='k',alpha=0.9,linewidth=0.8)
plt.fill_between(Q, 0, histData,color='C4',alpha=0.3)
plt.xlim(-8.0,8.0)
plt.xlabel(r'$\frac{\omega-\omega_0}{\alpha q_0 \sqrt{\epsilon_0}}$',fontsize=16);
plt.grid()

hilbertData = -np.imag(hilbert(histData))
plt.subplot(1,2,2)
for i in range(len(Emit)):
    plt.plot(2*np.pi*K/(Emit[i]**0.5*Xi0[i]*dw_dI),np.imag(Amp[i]))
plt.plot(Q,hilbertData,color='k',alpha=0.9,linewidth=0.8)
plt.fill_between(Q, 0, hilbertData,color='C4',alpha=0.3)
plt.xlabel(r'$\frac{\omega-\omega_0}{\alpha q_0 \sqrt{\epsilon_0}}$',fontsize=16);
plt.xlim(-8.0,8.0)
plt.grid()
plt.tight_layout()

# %% [markdown]
# ### artificial fitting <--- 1.35 factor

# %%
from scipy.signal import hilbert
plt.figure(figsize=(12,4))

plt.subplot(1,2,1)
for i in range(len(Emit)):
    plt.plot(2*np.pi*K/(Emit[i]**0.5*Xi0[i]*dw_dI)/1.35,np.real(Amp[i])*1.35)
plt.plot(Q,histData,color='k',alpha=0.9,linewidth=0.8)
plt.fill_between(Q, 0, histData,color='C4',alpha=0.3)
plt.xlim(-8.0,8.0)
plt.xlabel(r'$\frac{\omega-\omega_0}{\alpha q_0 \sqrt{\epsilon_0}}$',fontsize=16);
plt.grid()

hilbertData = -np.imag(hilbert(histData))
plt.subplot(1,2,2)
for i in range(len(Emit)):
    plt.plot(2*np.pi*K/(Emit[i]**0.5*Xi0[i]*dw_dI)/1.35,np.imag(Amp[i])*1.35)
plt.plot(Q,hilbertData,color='k',alpha=0.9,linewidth=0.8)
plt.fill_between(Q, 0, hilbertData,color='C4',alpha=0.3)
plt.xlabel(r'$\frac{\omega-\omega_0}{\alpha q_0 \sqrt{\epsilon_0}}$',fontsize=16);
plt.xlim(-8.0,8.0)
plt.grid()
plt.tight_layout()

# %% [markdown]
# # check emittance

# %%
NL_t = 0.4
NL_c = 0.01
NL_L = 1.8
NL_mu = 0.3

alfaEntrance = np.tan(np.pi*NL_mu)
betaEntrance = NL_L/np.sin(2.0*np.pi*NL_mu)

Me = 511005.0
ke = 100*1.0e6
freq = 30*1.0e6

# %%
import pImpactR as impact
pData = impact.readParticleData(-111114,ke,Me,freq)

# %%
Y =  pData[:,2]
Py = pData[:,3]

meanY = np.mean(Y)
meanPy = np.mean(Py)
Y = Y - meanY
Py = Py - meanPy

Py = Y*alfaEntrance/np.sqrt(betaEntrance)/NL_c + Py*np.sqrt(betaEntrance)/NL_c
Y  = Y/np.sqrt(betaEntrance)/NL_c

print(np.mean(Y**2+Py**2)/2,Emit[1])
# Out:
# 0.00014074770231523525 0.00014000000000000001
