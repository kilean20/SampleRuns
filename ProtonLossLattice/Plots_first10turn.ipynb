# %%
import pImpactR as impact
import numpy as np
import matplotlib.pyplot as plt
from copy import deepcopy as copy
import pickle
np.set_printoptions(formatter={'float': lambda x: format(x, '1.2E')})

# %%
import pickle
lostp_data = pickle.load(open('lostp_data.pickle','rb'))

# %%
lostp_data.keys()
# Out:
# dict_keys(['Thermal.tau=0.4.CL=3.0.noEspread.LinearMap', 'Thermal.tau=0.4.CL=2.7.noEspread.LinearMap', 'Thermal.tau=0.4.CL=2.6.noEspread.LinearMap', 'Thermal.tau=0.0.CL=3.0.noEspread.LinearMap', 'Thermal.tau=0.0.CL=2.7.noEspread.LinearMap', 'Thermal.tau=0.0.CL=2.4.noEspread.LinearMap', 'Thermal.tau=0.0.CL=2.2.noEspread.LinearMap', 'Thermal.tau=0.0.CL=2.3.noEspread.LinearMap', 'Thermal.tau=0.4.CL=3.0', 'Thermal.tau=0.4.CL=2.5', 'Thermal.tau=0.4.CL=2.2', 'Thermal.tau=0.0.CL=3.0', 'Thermal.tau=0.0.CL=2.5', 'Thermal.tau=0.0.CL=2.0', 'Thermal.tau=0.4.CL=2.1', 'Thermal.tau=0.0.CL=1.9', 'Thermal.tau=0.4.CL=2.0', 'Exponential.rmsMatched.CLx=2.5.CLy=2.5.noEspread.LinearMap', 'Exponential.rmsMatched.CLx=2.0.CLy=2.0.noEspread.LinearMap', 'Exponential.rmsMatched.CLx=3.0.CLy=3.0.noEspread.LinearMap', 'Exponential.rmsMatched.CLx=3.0.CLy=2.0.noEspread.LinearMap', 'Exponential.rmsMatched.CLx=3.0.CLy=1.5.noEspread.LinearMap', 'Thermal.tau=0.3.NLtau=0.3.CL=3.0.noEspread.LinearMap', 'Thermal.tau=0.3.NL
# ...

# %%
aperture = np.loadtxt('pipeinfo.in')
L=aperture[-1,0]

# %%
ap0_x,ap0_y = 0.00680513, 0.00935705
ap1_x,ap1_y = 4.00000000e-03, 5.50000000e-03
ang = np.arange(0.0,2*np.pi,2*np.pi/1024)
c = np.cos(ang)
s = np.sin(ang)

# %% [markdown]
# # Thermal

# %%
plt.figure(figsize=(8,4))

item = lostp_data['Thermal.tau=0.3.NLtau=0.3.CL=4.0.noEspread.LinearMap']
plt.subplot(231)
impact.plot.density(1000*item['pData0'][:,0],1000*item['pData0'][:,2])
plt.xlim(-5,8)
plt.ylim(-10,10)
plt.xticks([])
betx=np.round(item['Twiss0'][0],2)
alfx=np.round(item['Twiss0'][1],2)
emitx=np.round(1.0e6*item['Twiss0'][2],2)
bety=np.round(item['Twiss0'][3],2)
alfy=np.round(item['Twiss0'][4],2)
emity=np.round(1.0e6*item['Twiss0'][5],2)
plt.text(4,-7.8, bbox=dict(facecolor='white', alpha=0.5), fontsize=9,
         s = r'$\beta_x$:'+str(betx)+'\n'+r'$\alpha_x$:'+str(alfx)+'\n'+r'$\epsilon_x$:'+str(emitx)+'\n'
            +r'$\beta_y$:'+str(bety)+'\n'+r'$\alpha_y$:'+str(alfy)+'\n'+r'$\epsilon_y$:'+str(emity));
plt.subplot(234)
impact.plot.density(1000*item['pData1'][:,0],1000*item['pData1'][:,2])
plt.xlim(-5,8)
plt.ylim(-10,10)
plt.xticks([-4,-2,0,2,4]);
betx=np.round(item['Twiss1'][0],2)
alfx=np.round(item['Twiss1'][1],2)
emitx=np.round(1.0e6*item['Twiss1'][2],2)
bety=np.round(item['Twiss1'][3],2)
alfy=np.round(item['Twiss1'][4],2)
emity=np.round(1.0e6*item['Twiss1'][5],2)
plt.title(r'$\lambda=4.0$',fontsize=9)
plt.text(4,-7.8, bbox=dict(facecolor='white', alpha=0.5), fontsize=9,
         s = r'$\beta_x$:'+str(betx)+'\n'+r'$\alpha_x$:'+str(alfx)+'\n'+r'$\epsilon_x$:'+str(emitx)+'\n'
            +r'$\beta_y$:'+str(bety)+'\n'+r'$\alpha_y$:'+str(alfy)+'\n'+r'$\epsilon_y$:'+str(emity));



item = lostp_data['Thermal.tau=0.3.NLtau=0.3.CL=3.5.noEspread.LinearMap']
plt.subplot(232)
impact.plot.density(1000*item['pData0'][:,0],1000*item['pData0'][:,2])
plt.xlim(-5,8)
plt.ylim(-10,10)
plt.xticks([])
plt.yticks([])
betx=np.round(item['Twiss0'][0],2)
alfx=np.round(item['Twiss0'][1],2)
emitx=np.round(1.0e6*item['Twiss0'][2],2)
bety=np.round(item['Twiss0'][3],2)
alfy=np.round(item['Twiss0'][4],2)
emity=np.round(1.0e6*item['Twiss0'][5],2)
plt.text(4,-7.8, bbox=dict(facecolor='white', alpha=0.5), fontsize=9,
         s = r'$\beta_x$:'+str(betx)+'\n'+r'$\alpha_x$:'+str(alfx)+'\n'+r'$\epsilon_x$:'+str(emitx)+'\n'
            +r'$\beta_y$:'+str(bety)+'\n'+r'$\alpha_y$:'+str(alfy)+'\n'+r'$\epsilon_y$:'+str(emity));
plt.subplot(235)
impact.plot.density(1000*item['pData1'][:,0],1000*item['pData1'][:,2])
plt.xlim(-5,8)
plt.ylim(-10,10)
plt.xticks([-4,-2,0,2,4]);
plt.yticks([])
betx=np.round(item['Twiss1'][0],2)
alfx=np.round(item['Twiss1'][1],2)
emitx=np.round(1.0e6*item['Twiss1'][2],2)
bety=np.round(item['Twiss1'][3],2)
alfy=np.round(item['Twiss1'][4],2)
emity=np.round(1.0e6*item['Twiss1'][5],2)
plt.title(r'$\lambda=3.5$',fontsize=9)
plt.text(4,-7.8, bbox=dict(facecolor='white', alpha=0.5), fontsize=9,
         s = r'$\beta_x$:'+str(betx)+'\n'+r'$\alpha_x$:'+str(alfx)+'\n'+r'$\epsilon_x$:'+str(emitx)+'\n'
            +r'$\beta_y$:'+str(bety)+'\n'+r'$\alpha_y$:'+str(alfy)+'\n'+r'$\epsilon_y$:'+str(emity));



item = lostp_data['Thermal.tau=0.3.NLtau=0.3.CL=3.0.noEspread.LinearMap']
plt.subplot(233)
impact.plot.density(1000*item['pData0'][:,0],1000*item['pData0'][:,2])
plt.xlim(-5,8)
plt.ylim(-10,10)
plt.xticks([])
plt.yticks([])
betx=np.round(item['Twiss0'][0],2)
alfx=np.round(item['Twiss0'][1],2)
emitx=np.round(1.0e6*item['Twiss0'][2],2)
bety=np.round(item['Twiss0'][3],2)
alfy=np.round(item['Twiss0'][4],2)
emity=np.round(1.0e6*item['Twiss0'][5],2)
plt.text(4,-7.8, bbox=dict(facecolor='white', alpha=0.5), fontsize=9,
         s = r'$\beta_x$:'+str(betx)+'\n'+r'$\alpha_x$:'+str(alfx)+'\n'+r'$\epsilon_x$:'+str(emitx)+'\n'
            +r'$\beta_y$:'+str(bety)+'\n'+r'$\alpha_y$:'+str(alfy)+'\n'+r'$\epsilon_y$:'+str(emity));
plt.subplot(236)
impact.plot.density(1000*item['pData1'][:,0],1000*item['pData1'][:,2])
plt.xlim(-5,8)
plt.ylim(-10,10)
plt.xticks([-4,-2,0,2,4]);
plt.yticks([])
betx=np.round(item['Twiss1'][0],2)
alfx=np.round(item['Twiss1'][1],2)
emitx=np.round(1.0e6*item['Twiss1'][2],2)
bety=np.round(item['Twiss1'][3],2)
alfy=np.round(item['Twiss1'][4],2)
emity=np.round(1.0e6*item['Twiss1'][5],2)
plt.title(r'$\lambda=3.0$',fontsize=9)
plt.text(4,-7.8, bbox=dict(facecolor='white', alpha=0.5), fontsize=9,
         s = r'$\beta_x$:'+str(betx)+'\n'+r'$\alpha_x$:'+str(alfx)+'\n'+r'$\epsilon_x$:'+str(emitx)+'\n'
            +r'$\beta_y$:'+str(bety)+'\n'+r'$\alpha_y$:'+str(alfy)+'\n'+r'$\epsilon_y$:'+str(emity));


plt.savefig('xyDensityPlot.NLt=tau=0.3.png',dpi=180)

# %%
CL = [4.0,3.8]
for cl in CL:
    key = 'Thermal.tau=0.3.NLtau=0.3.CL='+str(cl)+'.noEspread.LinearMap'
    data = lostp_data[key]
    islost1 = len(data['pLost'].shape)==1
    if islost1:
        nlost=1
    else:
        nlost = len(data['pLost'])

    plt.figure(figsize=(12,6))


    plt.subplot(221)
    if islost1:
        plt.hist(data['pLost'][0]/L,bins=10,color='k');
    else:
        plt.hist(data['pLost'][:,0]/L,bins=10,color='k');
    plt.yscale('log')
    plt.legend(['total:'+str(nlost)])
    plt.xlabel('turn')
    plt.ylabel('count')


    plt.subplot(223)
    plt.plot(aperture[:,0],aperture[:,1]*100)
    plt.plot(aperture[:,0],aperture[:,2]*100)
    plt.legend(['x-pipe','y-pipe'],loc=2)
    plt.xlim(0,L)
    plt.ylabel('pipe size (cm)')
    plt.grid()
    plt.xlabel('s (m)')
    ax=plt.twinx()
    if islost1:
        plt.hist(np.mod(data['pLost'][0],L),bins=90,color='k');
    else:
        plt.hist(np.mod(data['pLost'][:,0],L),bins=90,color='k');
    plt.yscale('log')
    plt.ylabel('count')
    ax.yaxis.labelpad = -10
    plt.legend(['loss-histogram'],loc=4)
    plt.tick_params(which='both',direction='in')
    # plt.xlim(3,8)


    ax=plt.subplot(122)
    # alpha = np.min([1,10000/nlost])
    plt.plot(1000*ap0_x*c,1000*ap0_y*s,alpha=0.7,c='k',lw=2)
    plt.plot(1000*ap1_x*c,1000*ap1_y*s,alpha=0.7,c='k',lw=2)
    if islost1:
        plt.scatter(1000*data['pLost'][1],1000*data['pLost'][2])
    else:
        impact.plot.density(1000*data['pLost'][:,1],1000*data['pLost'][:,2])    
    # plt.scatter(data['pLost'][:,1],data['pLost'][:,2],s=1.0,alpha=alpha)
    plt.xlim(- 8, 8)
    plt.ylim(-12,12)
    plt.xlabel('x (mm)')
    plt.ylabel('y (mm)')
    ax.yaxis.tick_right()
    ax.yaxis.set_label_position('right')
    ax.yaxis.labelpad = 0

    plt.tight_layout()
    plt.savefig(key+'.png',dpi=180)

# %% [markdown]
# # Gaussian

# %%
plt.figure(figsize=(8,2.2))

item = lostp_data['Exponential.rmsMatched.CLx=3.0.CLy=3.0.noEspread.LinearMap']
plt.subplot(131)
impact.plot.density(1000*item['pData1'][:,0],1000*item['pData1'][:,2])
plt.xlim(-3,5)
plt.ylim(-8,8)
plt.xticks([-3,0,3]);
betx=np.round(item['Twiss1'][0],2)
alfx=np.round(item['Twiss1'][1],2)
emitx=np.round(1.0e6*item['Twiss1'][2],2)
bety=np.round(item['Twiss1'][3],2)
alfy=np.round(item['Twiss1'][4],2)
emity=np.round(1.0e6*item['Twiss1'][5],2)
plt.title(r'$\lambda_x=\lambda_y=3.0$',fontsize=9)
plt.text(2.8,-5.8, bbox=dict(facecolor='white', alpha=0.5), fontsize=9,
         s = r'$\beta_x$:'+str(betx)+'\n'+r'$\alpha_x$:'+str(alfx)+'\n'+r'$\epsilon_x$:'+str(emitx)+'\n'
            +r'$\beta_y$:'+str(bety)+'\n'+r'$\alpha_y$:'+str(alfy)+'\n'+r'$\epsilon_y$:'+str(emity));



item = lostp_data['Exponential.rmsMatched.CLx=2.5.CLy=2.5.noEspread.LinearMap']
plt.subplot(132)
impact.plot.density(1000*item['pData1'][:,0],1000*item['pData1'][:,2])
plt.xlim(-3,5)
plt.ylim(-8,8)
plt.xticks([-3,0,3]);
plt.yticks([])
betx=np.round(item['Twiss1'][0],2)
alfx=np.round(item['Twiss1'][1],2)
emitx=np.round(1.0e6*item['Twiss1'][2],2)
bety=np.round(item['Twiss1'][3],2)
alfy=np.round(item['Twiss1'][4],2)
emity=np.round(1.0e6*item['Twiss1'][5],2)
plt.title(r'$\lambda_x=\lambda_y=2.5$',fontsize=9)
plt.text(2.8,-5.8, bbox=dict(facecolor='white', alpha=0.5), fontsize=9,
         s = r'$\beta_x$:'+str(betx)+'\n'+r'$\alpha_x$:'+str(alfx)+'\n'+r'$\epsilon_x$:'+str(emitx)+'\n'
            +r'$\beta_y$:'+str(bety)+'\n'+r'$\alpha_y$:'+str(alfy)+'\n'+r'$\epsilon_y$:'+str(emity));



item = lostp_data['Exponential.rmsMatched.CLx=2.0.CLy=2.0.noEspread.LinearMap']
plt.subplot(133)
impact.plot.density(1000*item['pData1'][:,0],1000*item['pData1'][:,2])
plt.xlim(-3,5)
plt.ylim(-8,8)
plt.xticks([-3,0,3]);
plt.yticks([])
betx=np.round(item['Twiss1'][0],2)
alfx=np.round(item['Twiss1'][1],2)
emitx=np.round(1.0e6*item['Twiss1'][2],2)
bety=np.round(item['Twiss1'][3],2)
alfy=np.round(item['Twiss1'][4],2)
emity=np.round(1.0e6*item['Twiss1'][5],2)
plt.title(r'$\lambda_x=\lambda_y=2.0$',fontsize=9)
plt.text(2.8,-5.8, bbox=dict(facecolor='white', alpha=0.5), fontsize=9,
         s = r'$\beta_x$:'+str(betx)+'\n'+r'$\alpha_x$:'+str(alfx)+'\n'+r'$\epsilon_x$:'+str(emitx)+'\n'
            +r'$\beta_y$:'+str(bety)+'\n'+r'$\alpha_y$:'+str(alfy)+'\n'+r'$\epsilon_y$:'+str(emity));

plt.tight_layout()
plt.savefig('xyDensityPlot.RMSgaussian.png',dpi=180)

# %%
CL = [(3.0,2.0),(3.0,1.5)]
for clx,cly in CL:
    key = 'Exponential.rmsMatched.CLx='+str(clx)+'.CLy='+str(cly)+'.noEspread.LinearMap'
    data = lostp_data[key]
    islost1 = len(data['pLost'].shape)==1
    if islost1:
        nlost=1
    else:
        nlost = len(data['pLost'])

    plt.figure(figsize=(12,6))


    plt.subplot(221)
    if islost1:
        plt.hist(data['pLost'][0]/L,bins=10,color='k');
    else:
        plt.hist(data['pLost'][:,0]/L,bins=10,color='k');
    plt.yscale('log')
    plt.legend(['total:'+str(nlost)])
    plt.xlabel('turn')
    plt.ylabel('count')


    plt.subplot(223)
    plt.plot(aperture[:,0],aperture[:,1]*100)
    plt.plot(aperture[:,0],aperture[:,2]*100)
    plt.legend(['x-pipe','y-pipe'],loc=2)
    plt.xlim(0,L)
    plt.ylabel('pipe size (cm)')
    plt.grid()
    plt.xlabel('s (m)')
    ax=plt.twinx()
    if islost1:
        plt.hist(np.mod(data['pLost'][0],L),bins=90,color='k');
    else:
        plt.hist(np.mod(data['pLost'][:,0],L),bins=90,color='k');
    plt.yscale('log')
    plt.ylabel('count')
    ax.yaxis.labelpad = -10
    plt.legend(['loss-histogram'],loc=4)
    plt.tick_params(which='both',direction='in')
    # plt.xlim(3,8)


    ax=plt.subplot(122)
    # alpha = np.min([1,10000/nlost])
    plt.plot(1000*ap0_x*c,1000*ap0_y*s,alpha=0.7,c='k',lw=2)
    plt.plot(1000*ap1_x*c,1000*ap1_y*s,alpha=0.7,c='k',lw=2)
    if islost1:
        plt.scatter(1000*data['pLost'][1],1000*data['pLost'][2])
    else:
        impact.plot.density(1000*data['pLost'][:,1],1000*data['pLost'][:,2])    
    # plt.scatter(data['pLost'][:,1],data['pLost'][:,2],s=1.0,alpha=alpha)
    plt.xlim(- 8, 8)
    plt.ylim(-12,12)
    plt.xlabel('x (mm)')
    plt.ylabel('y (mm)')
    ax.yaxis.tick_right()
    ax.yaxis.set_label_position('right')
    ax.yaxis.labelpad = 0

    plt.tight_layout()
    plt.savefig(key+'.png',dpi=180)

# %%
data['pLost'].shape
