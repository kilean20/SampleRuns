# %%
import pImpactR as impact
import numpy as np
import matplotlib.pyplot as plt
from copy import deepcopy as copy
rectangular_ = 1
elliptic_ = 2

# %%
eSpread = 2.0e-22
emitGeomRMS = 3.3e-6

npt = 6400
nturn = 16

# %% [markdown]
# # read Aperture

# %%
aperture = np.loadtxt('pipeinfo.in')

# %%
plt.figure(figsize=(12,3))
plt.plot(aperture[:,0],aperture[:,1]*100)
plt.plot(aperture[:,0],aperture[:,2]*100)
plt.plot(aperture[:,0],(aperture[:,3]-1)*10,alpha=0.4)
plt.grid()
plt.ylim((0.2,3.5))
plt.xlim((0.0, 40))
plt.legend(('x','y'))
plt.xlabel('s (m)')
plt.ylabel('x or y aperture (cm)');

# %%
aperture[-1,0]
# Out:
# 39.968229720000004

# %% [markdown]
# # read impact lattice

# %%
beam,lattice = impact.readInputFile('test.Chad.in')

ke = beam.kinetic_energy
mass = beam.mass
freq = beam.frequency

g = ke/mass+1.0
bg = np.sqrt(g**2-1.0)
emitN = emitGeomRMS*bg
print('\n\n emitN =',emitN)
# Out:
# reading ImpactZ input file (test.Chad.in)
#   : mpi task info .............................done
#   : simulation control parameters .............done
#   : space charge field solver, mesh info ......done
#   : dist-type,restart,subcycle,#of state ......done
#   : Multiple Charge State info ................done
#   : particle distribution info ................done
#   : beam reference orbit info .................done
#   : converting impact dist to twiss param......done
#   : lattice info ..............................done
#
#
#  emitN = 2.4105916749973357e-07

# %%
beam.distribution.alfx = 3.860846841e-5
beam.distribution.betx = 0.561065822
beam.distribution.alfy = 2.282987698e-9
beam.distribution.bety = 1.385141718
beam.distribution.emitx = emitN
beam.distribution.emity = emitN
beam.distribution.betz  = 200
beam.distribution.alfz  = 0.0
beam.distribution.emitz = (eSpread*ke*1.0e-6)**2*beam.distribution.betz
beam.distribution.distribution_type = 'Gauss'
beam.n_particles = npt
beam.nCore_y = 8
beam.nCore_z = 4

# %%
cleanLat = []
pre = lattice[0]
L = 0 
for item in lattice:
    if item.type == 'RFkick':
        item.vmax = 0.0
    if item.type == 'nonlinear_insert':
        item.type = 'drift'
        print('NL:',L,L+item.length)
    if item.type not in ['-8', 'write_raw_ptcl', 'halt']:
        cleanLat.append(item)
    if 'length' in item:
        L = L+item.length
print(L-aperture[-1,0])
# Out:
# NL: 4.9115191429 6.711519142899999
# -4.199918635094946e-09

# %% [markdown]
# # run Impact

# %%
for item in cleanLat:
    if 'length' in item:
        item.n_sckick = int(np.ceil(item.length*50))
        item.n_map = 1

# %%
cleanLat.insert(0,impact.getElem('pipeinfo'))
cleanLat[1].turns = nturn

# %%
writeP = impact.getElem('write_raw_ptcl')
writeP.file_id = 3456
writeP.format_id = 2
cleanLat.insert(2,writeP)

# %%
writeP2 = impact.getElem('write_raw_ptcl')
writeP2.file_id = 7890
writeP2.format_id = 2
writeP2.turn = nturn
cleanLat.append(writeP2)

# %%
impact.writeInputFile(beam,cleanLat)
impact.run(beam)
# Out:
# 0

# %%
pData1 = impact.readParticleData(3456,ke,mass,freq,2)

# %%
pData2 = impact.readParticleData(7890,ke,mass,freq,2)

# %%
plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
plt.scatter(pData1[:,0],pData1[:,1],s=1.0)
plt.scatter(pData2[:,0],pData2[:,1],s=1.0)
plt.subplot(2,2,2)
plt.scatter(pData1[:,2],pData1[:,3],s=1.0)
plt.scatter(pData2[:,2],pData2[:,3],s=1.0)
plt.subplot(2,2,3)
plt.scatter(pData1[:,4],pData1[:,5],s=1.0)
plt.scatter(pData2[:,4],pData2[:,5],s=1.0)
plt.subplot(2,2,4)
plt.scatter(pData1[:,0],pData1[:,2],s=1.0)
plt.scatter(pData2[:,0],pData2[:,2],s=1.0)

# %%
np.std(pData1[:,5]/ke)
# Out:
# 1.9804861777092304e-22

# %%
# lostp = np.loadtxt('lost_partcl.data',skiprows=1, usecols=(0,1,2,4))

# %%
lostp = np.load('lost_partcl.noEspread.npy')
# np.save('lost_partcl.noEspread.npy',lostp)

# %%
plt.figure(figsize=(12,3))
plt.hist(lostp[:,0]/L,bins=200,color='k');
plt.xlim(0,16)
plt.yscale('log')

# %%
lostp[:,0] = np.mod(lostp[:,0],L)
lostp.shape
# Out:
# (266, 4)

# %%
plt.figure(figsize=(12,3))
plt.hist(lostp[:,0],bins=40,color='k');
plt.xlim(0,L)
plt.yscale('log')
plt.twinx()
plt.plot(aperture[:,0],aperture[:,1]*100)
plt.plot(aperture[:,0],aperture[:,2]*100)

# %%
plt.figure(figsize=(12,12))
plt.scatter(lostp[:,1],lostp[:,2],s=4.0)
plt.xlim(-0.012,0.012)
plt.ylim(-0.012,0.012)
# Out:
# (-0.012, 0.012)
