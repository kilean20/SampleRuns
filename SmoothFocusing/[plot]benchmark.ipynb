# %%
import pImpactR as impact
import numpy as np
import matplotlib.pyplot as plt
import pickle

# %%
with open('./Lambda5/X.Lambda5.100sckick.10map.pickle','rb') as f:
    X5_100_10 = pickle.load(f) 
with open('./Lambda10/X.Lambda10.100sckick.10map.pickle','rb') as f:
    X10_100_10 = pickle.load(f)
with open('./Lambda5/X.Lambda5.50sckick.5map.pickle','rb') as f:
    X5_50_5 = pickle.load(f) 
with open('./Lambda10/X.Lambda10.50sckick.5map.pickle','rb') as f:
    X10_50_5 = pickle.load(f)     
with open('./Lambda5/Y.Lambda5.100sckick.10map.pickle','rb') as f:
    Y5_100_10 = pickle.load(f) 
with open('./Lambda10/Y.Lambda10.100sckick.10map.pickle','rb') as f:
    Y10_100_10 = pickle.load(f)

# %%
plt.plot(X5_100_10.s,X5_100_10.rms_x/X5_100_10.rms_x[0]-1.0)
plt.plot(X10_100_10.s,X10_100_10.rms_x/X10_100_10.rms_x[0]-1.0)

# %%
plt.plot(Y5_100_10.s,Y5_100_10.rms_y/Y5_100_10.rms_y[0]-1.0)
plt.plot(Y10_100_10.s,Y10_100_10.rms_y/Y10_100_10.rms_y[0]-1.0)

# %%
plt.plot(X5_100_10.s,X5_100_10.rms_x/X5_100_10.rms_x[0]-1.0)
plt.plot(X5_50_5.s,X5_50_5.rms_x/X5_50_5.rms_x[0]-1.0)
plt.plot(X10_100_10.s,X10_100_10.rms_x/X10_100_10.rms_x[0]-1.0)
plt.plot(X10_50_5.s,X10_50_5.rms_x/X10_50_5.rms_x[0]-1.0)
