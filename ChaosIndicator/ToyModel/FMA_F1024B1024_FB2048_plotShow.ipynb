# %%
from IPython.display import Image
dTune = 0
path = './'
extension = str(dTune)+'.png'

# %% [markdown]
# # Alive particles

# %% [markdown]
# ### Dynamic Aperture

# %% [markdown]
# ##### FMA

# %%
Image(filename=path+'DA.FMA.'+extension)

# %% [markdown]
# ##### Forward$\times$nTurn then Backword$\times$nTurn

# %%
Image(filename=path+'DA.B.'+extension)

# %% [markdown]
# ##### Forward-Backword$\times$nTurn

# %%
Image(filename=path+'DA.FB.'+extension)

# %% [markdown]
# ### Invariants

# %% [markdown]
# ##### FMA

# %%
Image(filename=path+'Invariant.FMA.'+extension)

# %% [markdown]
# ##### Forward$\times$nTurn then Backword$\times$nTurn

# %%
Image(filename=path+'Invariant.B.'+extension)

# %% [markdown]
# ##### Forward-Backword$\times$nTurn

# %%
Image(filename=path+'Invariant.FB.'+extension)

# %% [markdown]
# ### FMA tune plot

# %%
Image(filename=path+'FMA.'+extension)

# %% [markdown]
# ### FFT

# %%
Image(filename=path+'FFT.'+extension)

# %% [markdown]
# ### Poincare

# %% [markdown]
# ##### FMA

# %%
Image(filename=path+'Poincare.FMA.'+extension)

# %% [markdown]
# ##### Forward$\times$nTurn then Backword$\times$nTurn

# %%
Image(filename=path+'Poincare.B.'+extension)

# %% [markdown]
# ##### Forward-Backword$\times$nTurn

# %%
Image(filename=path+'Poincare.FB.'+extension)

# %% [markdown]
# # Lost particles

# %% [markdown]
# ### Dynamic Aperture

# %%
Image(filename=path+'DA.Lost.'+extension)

# %% [markdown]
# ### Invariants

# %%
Image(filename=path+'Invariant.Lost.'+extension)

# %% [markdown]
# ### FFT

# %%
Image(filename=path+'FFT.Lost.'+extension)

# %% [markdown]
# ### FMA tune plot

# %%
Image(filename=path+'FMA.Lost.'+extension)

# %% [markdown]
# ### Poincare

# %%
Image(filename=path+'Poincare.Lost.'+extension)

# %% [markdown]
# # Read Log

# %%
with open(path+'log.'+str(dTune)) as f:
    print(f.read())
# Out:
# reading ImpactZ input file (test_toymodel.in)
#   : mpi task info .............................done
#   : simulation control parameters .............done
#   : space charge field solver, mesh info ......done
#   : dist-type,restart,subcycle,#of state ......done
#   : Multiple Charge State info ................done
#   : particle distribution info ................done
#   : beam reference orbit info .................done
#   : converting impact dist to twiss param......done
#   : lattice info ..............................done
# initial npt= 7860
# ...
# =========== FMA ===========
# ...
# input error <- sum(beam.multi_charge.n_particles) not qual to beam.n_particles
#   ... enforcing  beam.multi_charge.n_particles[0] to beam.n_particles
# input error <- beam.multi_charge.current[0] not qual to beam.current
#   ... enforcing  beam.multi_charge.current[0] to beam.current
# TBTdata.shape = (2048, 6, 6656)
# nptLost,nptLive = 1204 6656
# max(Xdiff) 0.0947612350131975
# max(Ydiff) 0.994140625
# ...
