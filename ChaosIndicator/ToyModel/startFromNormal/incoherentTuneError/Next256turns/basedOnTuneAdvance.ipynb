# %%
import numpy as np
import pImpactR as impact
from copy import deepcopy as copy
import matplotlib.pyplot as plt
import sys
import pickle
np.set_printoptions(formatter={'float': lambda x: format(x, '1.2E')})

# %%
mu_at = 1
nturn = 256
nCore_y = 1
nCore_z = 1

NL_c = 0.01
NL_t = 0.4
NL_nu= 0.3
NL_L = 1.8
dTune = 0.0

alfx = np.tan(np.pi*NL_nu)
betx = NL_L/np.sin(2.0*np.pi*NL_nu)

pipe_radius = 0.02*np.sqrt(2.0)

# %% [markdown]
# # 1. Preparation

# %% [markdown]
# ### 1.1 read InputFile and simplify lattice

# %%
beam, lattice = impact.readInputFile('../../test_toymodel.in');
beam.nCore_y = nCore_y
beam.nCore_z = nCore_z
beam.distribution.distribution_type = 'ReadFile'
beam.current = 0.0
beam.n_particles = 1

ke = beam.kinetic_energy
mass = beam.mass
freq = beam.frequency
# Out:
# reading ImpactZ input file (../../test_toymodel.in)
#   : mpi task info .............................done
#   : simulation control parameters .............done
#   : space charge field solver, mesh info ......done
#   : dist-type,restart,subcycle,#of state ......done
#   : Multiple Charge State info ................done
#   : particle distribution info ................done
#   : beam reference orbit info .................done
#   : converting impact dist to twiss param......done
#   : lattice info ..............................done

# %%
for i in range(len(lattice)-1,0,-1):
    if lattice[i].type == 'write_raw_ptcl':
        lattice.pop(i)
lattice[1].n_sckick = 100
lattice[1].length = NL_L
lattice[1].strength_t = NL_t
lattice[1].transverse_scale_c = NL_c
lattice[1].tune_advance = NL_nu
lattice[1].pipe_radius = 0.02*np.sqrt(2)

lattice[2].tune_advance = dTune
lattice[2].nonlinear_insert_tuneAdvance = NL_nu
lattice[2].nonlinear_insert_length = NL_L

TBT = impact.getElem('TBT')
TBT.file_id = nturn
TBT.pID_begin = 1
TBT.pID_end = 1
lattice.insert(1,TBT)

OUTPUT = impact.getElem('write_raw_ptcl')
OUTPUT.file_id = nturn
OUTPUT.turn = nturn
OUTPUT.format_id = 2
lattice.append(OUTPUT)

# %%
def normalize(data):
    data[:,1] = (data[:,0]*alfx/np.sqrt(betx) + data[:,1]*np.sqrt(betx))/NL_c
    data[:,3] = (data[:,2]*alfx/np.sqrt(betx) + data[:,3]*np.sqrt(betx))/NL_c
    data[:,0] = data[:,0]/(np.sqrt(betx)*NL_c)
    data[:,2] = data[:,2]/(np.sqrt(betx)*NL_c)
    
def unnormalize(data):
    data[:,1] = (-data[:,0]*alfx + data[:,1])*NL_c/np.sqrt(betx)
    data[:,3] = (-data[:,2]*alfx + data[:,3])*NL_c/np.sqrt(betx)
    data[:,0] = data[:,0]*np.sqrt(betx)*NL_c
    data[:,2] = data[:,2]*np.sqrt(betx)*NL_c

# %%
data = pickle.load(open('tune_advance.pickle','rb'))
data['pData'].shape
# Out:
# (3624, 9)

# %%
data['Mu']
# Out:
# {'0': {'mux': array([2.88E-02, 2.88E-02, 2.87E-02, ..., 2.86E-02, 2.86E-02, 2.85E-02]),
#   'muy': array([2.66E-02, 2.64E-02, 2.63E-02, ..., 2.62E-02, 2.61E-02, 2.60E-02])},
#  '1': {'mux': array([2.80E-02, 2.78E-02, 2.75E-02, ..., 2.74E-02, 2.74E-02, 2.74E-02]),
#   'muy': array([2.42E-02, 2.24E-02, 2.15E-02, ..., 2.25E-02, 2.32E-02, 2.32E-02])},
#  '2': {'mux': array([2.86E-02, 2.86E-02, 2.86E-02, ..., 2.86E-02, 2.85E-02, 2.85E-02]),
#   'muy': array([2.61E-02, 2.62E-02, 2.62E-02, ..., 2.62E-02, 2.61E-02, 2.60E-02])},
#  '3': {'mux': array([2.82E-02, 2.80E-02, 2.77E-02, ..., 2.75E-02, 2.73E-02, 2.74E-02]),
#   'muy': array([2.49E-02, 2.32E-02, 2.19E-02, ..., 2.23E-02, 2.32E-02, 2.32E-02])},
#  '4': {'mux': array([2.85E-02, 2.85E-02, 2.85E-02, ..., 2.85E-02, 2.87E-02, 2.88E-02]),
#   'muy': array([2.58E-02, 2.58E-02, 2.60E-02, ..., 2.61E-02, 2.61E-02, 2.59E-02])},
#  'ave[0~5]': {'mux': array([2.84E-02, 2.83E-02, 2.82E-02, ..., 2.81E-02, 2.81E-02, 2.81E-02]),
#   'muy': array([2.55E-02, 2.48E-02, 2.44E-02, ..., 2.47E-02, 2.49E-02, 2.49E-02])}}

# %%
npt0 = data['pData'].shape[0]
unnormalize(data['pData'])
plt.scatter(data['pData'][:,0],data['pData'][:,2])
plt.ylim(-0.001,0.015)
plt.xlim(-0.015,0.015)
# Out:
# (-0.015, 0.015)

# %%
lattice[0].turns = nturn

def run(pTest,dx,dy):
    lattice[3].tune_advance_x = dx
    lattice[3].tune_advance_y = dy
    TBT.file_id = nturn
    OUTPUT.file_id = nturn
    
    beam.distribution.distribution_type = 'ReadFile'
    impact.writeParticleData(pTest, ke, mass, freq)
    impact.writeInputFile(beam,lattice) 
    impact.run(beam)
    print(impact.readLostAt(-1))
    if impact.readLostAt(-1) == 0:
        return False
    tmp,tbt0 = impact.readTBT(nturn,ke,mass,freq)
    assert tbt0.shape == (nturn,6,1)
    
    TBT.file_id = nturn*2
    OUTPUT.file_id = nturn*2
    beam.distribution.distribution_type = 'ReadFile_binary'
    beam.distribution.file_id = nturn
    impact.writeInputFile(beam,lattice) 
    impact.run(beam)
    print(impact.readLostAt(-1))
    if impact.readLostAt(-1) == 0:
        return False
    tmp,tbt1 = impact.readTBT(2*nturn,ke,mass,freq)
    assert tbt1.shape == (nturn,6,1)
    
    return tbt0[:,:4,0],tbt1[:,:4,0]

# %%
TBTdata = np.zeros([2*nturn,4,npt0])
ipt = 0
for i in range(npt0):  
    print(i,ipt)
    pTest = np.zeros([1,9])
    pTest[0,-1] = 1
    pTest[0,-3] = beam.multi_charge.q_m[0]
    pTest[0,:4] = data['pData'][i,:4]
    dx = data['Mu'][str(mu_at)]['mux'][i]
    dy = data['Mu'][str(mu_at)]['muy'][i]
    tmp = run(pTest,dx,dy)
    if tmp:
        TBTdata[:nturn,:,ipt] = tmp[0]
        TBTdata[nturn:,:,ipt] = tmp[1]
        ipt=ipt+1
npt = ipt
TBT=TBTdata[:,:,:npt]
# Out:
# 0 0
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 0
# 1 0
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 2 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 0
# 3 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 0
# 4 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 5 2
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 0
# 6 2
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 0
# 7 2
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 8 3
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 0
# 9 3
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 0
# 10 3
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 0
# 11 3
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 12 4
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 13 5
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 0
# 14 5
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 0
# 15 5
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 0
# 16 5
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 0
# 17 5
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 0
# 18 5
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 0
# 19 5
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 0
# 20 5
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 21 6
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 22 7
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 23 8
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 24 9
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 25 10
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 26 11
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 27 12
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 28 13
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 0
# 29 13
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 0
# 30 13
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 31 14
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 0
# 32 14
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 33 15
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 34 16
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 35 17
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 36 18
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 0
# 37 18
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 38 19
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 39 20
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 40 21
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 41 22
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 42 23
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 43 24
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 44 25
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 45 26
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 46 27
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 47 28
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 48 29
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 49 30
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 50 31
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 51 32
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 52 33
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 0
# 53 33
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 54 34
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 55 35
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 56 36
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 57 37
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 58 38
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 59 39
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 60 40
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 61 41
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 62 42
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 63 43
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 64 44
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 65 45
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 66 46
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 67 47
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 68 48
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 69 49
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 70 50
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 71 51
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 72 52
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 73 53
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 74 54
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 75 55
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 76 56
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 77 57
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 78 58
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 79 59
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 80 60
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 81 61
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 82 62
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 83 63
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 84 64
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 85 65
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 86 66
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 87 67
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 88 68
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 89 69
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 0
# 90 69
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 0
# 91 69
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 92 70
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 0
# 93 70
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 0
# 94 70
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 95 71
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 96 72
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 97 73
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 98 74
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 99 75
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 100 76
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 101 77
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 102 78
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 103 79
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 104 80
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 105 81
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 106 82
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 107 83
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 108 84
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 109 85
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 110 86
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 111 87
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 0
# 112 87
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 0
# 113 87
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 0
# 114 87
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 115 88
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 0
# 116 88
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 117 89
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 118 90
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 119 91
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 120 92
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 121 93
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 0
# 122 93
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 123 94
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 124 95
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 125 96
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 126 97
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 127 98
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 128 99
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 129 100
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 130 101
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 131 102
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 132 103
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 133 104
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 134 105
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 135 106
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 136 107
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 137 108
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 138 109
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 139 110
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 140 111
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 141 112
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 142 113
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 143 114
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 144 115
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 0
# 145 115
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 146 116
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 147 117
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 148 118
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 149 119
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 150 120
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 151 121
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 152 122
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 153 123
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 154 124
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 155 125
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 156 126
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 157 127
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 158 128
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 159 129
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 160 130
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 161 131
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 162 132
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 163 133
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 164 134
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 165 135
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 166 136
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 167 137
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 168 138
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 169 139
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 170 140
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 171 141
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 172 142
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 173 143
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 174 144
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 0
# 175 144
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 176 145
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 0
# 177 145
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 0
# 178 145
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 179 146
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 0
# 180 146
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 0
# 181 146
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 182 147
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 183 148
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 184 149
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 185 150
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 186 151
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 187 152
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 188 153
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 189 154
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 190 155
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 191 156
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 192 157
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 193 158
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 194 159
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 195 160
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 196 161
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 197 162
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 198 163
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 199 164
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 200 165
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 201 166
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 202 167
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 203 168
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 204 169
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 205 170
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 206 171
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 207 172
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 208 173
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 209 174
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 210 175
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 211 176
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 212 177
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 213 178
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 214 179
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 215 180
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 216 181
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 217 182
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 218 183
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 219 184
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 220 185
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 221 186
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 222 187
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 223 188
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 224 189
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 225 190
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 226 191
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 227 192
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 228 193
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 229 194
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 230 195
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 231 196
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 232 197
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 233 198
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 234 199
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 235 200
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 236 201
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 237 202
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 238 203
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 239 204
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 240 205
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 241 206
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 242 207
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 243 208
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 244 209
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 245 210
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 246 211
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 247 212
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 248 213
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 249 214
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 250 215
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 251 216
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 252 217
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 253 218
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 254 219
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 255 220
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 256 221
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 257 222
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 258 223
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 259 224
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 260 225
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 261 226
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 262 227
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 263 228
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 264 229
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 265 230
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 266 231
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 267 232
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 268 233
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 269 234
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 270 235
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 271 236
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 272 237
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 273 238
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 274 239
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 275 240
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 276 241
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 277 242
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 278 243
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 279 244
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 280 245
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 281 246
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 282 247
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 283 248
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 284 249
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 285 250
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 286 251
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 287 252
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 288 253
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 289 254
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 290 255
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 291 256
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 292 257
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 293 258
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 294 259
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 295 260
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 296 261
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 297 262
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 298 263
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# ...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 525 483
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 526 484
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 527 485
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 528 486
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 529 487
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 530 488
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 531 489
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 532 490
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 533 491
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 534 492
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 535 493
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 536 494
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 537 495
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 538 496
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 539 497
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 540 498
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 541 499
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 542 500
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 543 501
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 544 502
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 545 503
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 546 504
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 547 505
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 548 506
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 549 507
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 550 508
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 551 509
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 552 510
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 553 511
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 554 512
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 555 513
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 0
# 556 513
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 557 514
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 558 515
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 559 516
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 560 517
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 561 518
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 562 519
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 563 520
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 564 521
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 565 522
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 566 523
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 567 524
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 568 525
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 569 526
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 570 527
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 571 528
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 572 529
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 573 530
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 574 531
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 575 532
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 576 533
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 577 534
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 578 535
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 579 536
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 580 537
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 581 538
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 582 539
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 583 540
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 584 541
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 585 542
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 586 543
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 587 544
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 588 545
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 589 546
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 590 547
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 591 548
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 592 549
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 593 550
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 594 551
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 595 552
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 596 553
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 597 554
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 598 555
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 599 556
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 600 557
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 601 558
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 602 559
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 603 560
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 604 561
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 605 562
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 606 563
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 607 564
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 608 565
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 609 566
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 610 567
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 611 568
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 612 569
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 613 570
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 614 571
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 615 572
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 616 573
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 617 574
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 618 575
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 619 576
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...
# 1
# 620 577
# IMPACTz: linear dipoel finge model and linear drift propagator is assumed...

# %%
X = (TBT[:,0,:] - 1j*(betx*TBT[:,1,:]+alfx*TBT[:,0,:]))/(NL_c*np.sqrt(betx))
Y = (TBT[:,2,:] - 1j*(betx*TBT[:,3,:]+alfx*TBT[:,2,:]))/(NL_c*np.sqrt(betx))
dummy,npt = X.shape

# %%
plt.scatter(np.real(X[0,:]),np.real(Y[0,:]),s=1.0)

# %% [markdown]
# ### Apply NAFF

# %%
def getClosestDiff(ref,arr):
    # ref.shape = nSample
    nMode = len(arr)
    if ref>1.0:
        ref = ref - 1.0
    for i in range(nMode):
        if arr[i]>1.0:
            arr[i]=arr[i]-1.0
    diff = np.abs(ref-arr)
    for i in range(nMode):
        if (diff[i]>0.5):
            diff[i] = 1.0 - diff[i]
    return np.min(diff)

# %%
tuneXbefore = np.zeros(npt)
tuneYbefore = np.zeros(npt)
Adiff = np.zeros(npt)
for i in range(npt):
    signal = X[:nturn,i] -np.mean(X[:nturn,i])
    tuneXbefore[i],amp,dummy = impact.util.naff(1,signal,window_id=1)
    signal = X[nturn:,i] -np.mean(X[nturn:,i])
    tune,amp,dummy = impact.util.naff(3,signal,window_id=1)
    xdiff = getClosestDiff(tuneXbefore[i],tune)

    signal = Y[:nturn,i] -np.mean(Y[:nturn,i])
    tuneYbefore[i],amp,dummy = impact.util.naff(1,signal,window_id=1)
    signal = Y[nturn:,i] -np.mean(Y[nturn:,i])
    tune,amp,dummy = impact.util.naff(3,signal,window_id=1)
    ydiff = getClosestDiff(tuneYbefore[i],tune) 
    Adiff[i] = np.log10(np.sqrt(xdiff**2 +ydiff**2)+1.0e-6)

# %% [markdown]
# ### Plot

# %% [markdown]
# ##### DA

# %%
xmax = 0.98
plt.figure(figsize=[4,3.3])
f1=plt.scatter(np.real(X[0,:]), np.real(Y[0,:]),c=Adiff,s=1.6,marker='s')
f1=plt.scatter(np.real(X[0,:]),-np.real(Y[0,:]),c=Adiff,s=1.6,marker='s')
plt.scatter([-1.0,1.0],[0.0,0.0],c='r',s=77,marker='x')
plt.xlim(-xmax*1.1,xmax*1.1)
plt.ylim(-xmax*1.1,xmax*1.1)
plt.xlabel('$x_n$')
plt.ylabel('$y_n$')
plt.colorbar(f1)
plt.tight_layout()
plt.savefig('FMA.DA.nu='+str(NL_nu)+'.tau='+str(NL_t)+'.mux,muy=measured_from_'+str(mu_at)+'.turn='+str(nturn)+'.png',dpi=180)

# %% [markdown]
# # FB

# %% [markdown]
# ### Run Backward

# %%
lattice[-1].file_id = nturn
lattice[-1]

# %%
lattice[1].file_id = nturn
lattice[1]

# %%
latticeB = copy(lattice[1:-1][::-1])
latticeB.insert(0,copy(lattice[0]))

for i in range(len(latticeB)):
    if 'length' in latticeB[i]:
        latticeB[i].length = -latticeB[i].length
    if latticeB[i].type == 'linear_matrix_map':
        latticeB[i].tune_advance                 =-latticeB[i].tune_advance
        latticeB[i].nonlinear_insert_tuneAdvance =-latticeB[i].nonlinear_insert_tuneAdvance
        latticeB[i].nonlinear_insert_length      =-latticeB[i].nonlinear_insert_length

# %%
for item in lattice:
    print(item.type)

# %%
for item in latticeB:
    print(item.type)

# %%
def run(pTest,dx,dy):
    lattice[3].tune_advance_x = dx
    lattice[3].tune_advance_y = dy
    latticeB[1].tune_advance_x = -dx
    latticeB[1].tune_advance_y = -dy
    

    beam.distribution.distribution_type = 'ReadFile'
    impact.writeParticleData(pTest, ke, mass, freq)
    impact.writeInputFile(beam,lattice) 
    impact.run(beam)
    print(impact.readLostAt(-1))
    if impact.readLostAt(-1) == 0:
        return False
    tmp,tbt0 = impact.readTBT(nturn,ke,mass,freq)
    assert tbt0.shape == (nturn,6,1)
    
    
    beam.distribution.distribution_type = 'ReadFile_binary'
    beam.distribution.file_id = nturn
    impact.writeInputFile(beam,latticeB) 
    impact.run(beam)
    print(impact.readLostAt(-1))
    if impact.readLostAt(-1) == 0:
        return False
    tmp,tbt1 = impact.readTBT(nturn,ke,mass,freq)
    assert tbt1.shape == (nturn,6,1)
    
    return tbt0[:,:4,0],tbt1[::-1,:4,0]

# %%
TBTF = np.zeros([nturn,4,npt0])
TBTB = np.zeros([nturn,4,npt0])
ipt = 0
for i in range(npt0):  
    print(i,ipt)
    pTest = np.zeros([1,9])
    pTest[0,-1] = 1
    pTest[0,-3] = beam.multi_charge.q_m[0]
    pTest[0,:4] = data['pData'][i,:4]
    dx = data['Mu'][str(mu_at)]['mux'][i]
    dy = data['Mu'][str(mu_at)]['muy'][i]
    tmp = run(pTest,dx,dy)
    if tmp:
        TBTF[:,:,ipt] = tmp[0]
        TBTB[:,:,ipt] = tmp[1]
        ipt=ipt+1
npt = ipt

# %%
TBTF=TBTF[:,:,:npt]
TBTB=TBTB[:,:,:npt]

# %%
XF = (TBTF[:,0,:] - 1j*(betx*TBTF[:,1,:]+alfx*TBTF[:,0,:]))/(NL_c*np.sqrt(betx))
YF = (TBTF[:,2,:] - 1j*(betx*TBTF[:,3,:]+alfx*TBTF[:,2,:]))/(NL_c*np.sqrt(betx))

# %%
XB = (TBTB[:,0,:] - 1j*(betx*TBTB[:,1,:]+alfx*TBTB[:,0,:]))/(NL_c*np.sqrt(betx))
YB = (TBTB[:,2,:] - 1j*(betx*TBTB[:,3,:]+alfx*TBTB[:,2,:]))/(NL_c*np.sqrt(betx))

# %%
plt.plot(TBTF[-22:-1,0,2])
plt.plot(TBTB[-22:-1,0,2])

# %%
Adiff = np.abs(XF-XB)**2+np.abs(YF-YB)**2
Adiff = np.log10(np.sqrt(np.sum(Adiff,0)/nturn))

# %% [markdown]
# ### Plot

# %% [markdown]
# ##### DA

# %%
plt.figure(figsize=[4,3.3])
f1=plt.scatter(np.real(XF[0,:]), np.real(YF[0,:]),c=Adiff,s=1.6,marker='s')
f1=plt.scatter(np.real(XF[0,:]),-np.real(YF[0,:]),c=Adiff,s=1.6,marker='s')
plt.scatter([-1.0,1.0],[0.0,0.0],c='r',s=77,marker='x')
plt.xlim(-xmax*1.1,xmax*1.1)
plt.ylim(-xmax*1.1,xmax*1.1)
plt.xlabel('$x_n$')
plt.ylabel('$y_n$')
plt.colorbar(f1)
plt.tight_layout()
plt.savefig('FB.DA.nu='+str(NL_nu)+'.tau='+str(NL_t)+'.mux,muy=measured_from_'+str(mu_at)+'.turn='+str(nturn)+'.png',dpi=180)
