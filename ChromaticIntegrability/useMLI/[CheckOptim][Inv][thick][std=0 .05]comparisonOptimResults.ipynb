# %%
import numpy as np
import os
from pImpactR import MLI as mli
from pImpactR import opt
from pImpactR.util import Me
from copy import deepcopy as copy
import time
import pickle
import pandas as pd
import matplotlib.pyplot as plt

# %%
nturn = 2048
npt = 64
std = 0.05
Espread = 2.0e-3

# %% [markdown]
# # Read MLI input for settings

# %%
elems,latticeList,labor = mli.readInputfile('mli.in.t3_iota_8_4_t0p4.optimized')
# elems[2].driftexact=1
# Out:
# setarclen is not recognized. skipping...
# autoconcat is not recognized. skipping...
# autoapply is not recognized. skipping...
# reftraj is not recognized. skipping...
# fit is not recognized. skipping...
# bip is not recognized. skipping...
# tip is not recognized. skipping...

# %%
energy=elems[0].energy*1.0e9
gam0 = energy/Me
bet0 = np.sqrt(1.0-1.0/gam0**2)

# %%
elemList = []
for item in elems:
    if not item.elem in ['tasm','aim','vary','anaprint','monitor']:
        elemList.append(item)

# %%
NL_nu = 0.3
NL_L  = 1.8
NL_c  = 0.01
NL_t  = 0.4
alfx = np.tan(np.pi*NL_nu)
betx = NL_L/np.sin(2.0*np.pi*NL_nu)
k = 2*alfx/betx


f3 = k/(2*bet0)
f4 = k/(2*bet0*gam0)**2
print(bet0,k,f3,f4)
# Out:
# 0.99999423665409 1.4544633270832747 0.727235854853427 4.191323867725334e-06

# %%
def MLI2norm(data_in,sign=1):
    data=data_in.copy()
#     data[:,5] = -bet0*data[:,5]*(1.0+0.5*data[:,5]/gam0**2-0.5*(bet0/gam0)**2*data[:,5]*data[:,5])
#     data[:,5] = -bet0*data[:,5]*(1.0+0.5*data[:,5]/gam0**2-0.5*(bet0/gam0)**2*data[:,5]*data[:,5])
    data[:,5] = np.sqrt(1.0-2.0*data[:,5]/bet0+data[:,5]**2)-1.0
    data[:,1] = (data[:,0]*alfx*sign/np.sqrt(betx) + data[:,1]/(1+data[:,5])*np.sqrt(betx))/NL_c
    data[:,3] = (data[:,2]*alfx*sign/np.sqrt(betx) + data[:,3]/(1+data[:,5])*np.sqrt(betx))/NL_c
    data[:,0] = data[:,0]/(np.sqrt(betx)*NL_c)
    data[:,2] = data[:,2]/(np.sqrt(betx)*NL_c)
    return data
    
def norm2MLI(data_in,sign=1):
    data=data_in.copy()
    data[:,1] = (-data[:,0]*alfx*sign + data[:,1])*NL_c/np.sqrt(betx)*(1+data[:,5])
    data[:,3] = (-data[:,2]*alfx*sign + data[:,3])*NL_c/np.sqrt(betx)*(1+data[:,5])
    data[:,0] = data[:,0]*np.sqrt(betx)*NL_c
    data[:,2] = data[:,2]*np.sqrt(betx)*NL_c
#     data[:,5] = -data[:,5]/bet0-0.5*(data[:,5]/(bet0*gam0))**2-0.5*(data[:,5]/(bet0*gam0))**3*gam0
    data[:,5] = -np.sqrt((1.0+data[:,5])**2+1.0/(bet0*gam0)**2)+1.0/bet0
    return data

# %%
from scipy.stats import truncnorm

def get_truncated_normal(mean=0, sd=1, low=0, upp=10,n=1):
    f = truncnorm(
        (low - mean) / sd, (upp - mean) / sd, loc=mean, scale=sd)
    return f.rvs(n)

# %%
x=get_truncated_normal(sd=std,low=-2.0*std,upp=2.0*std,n=npt*5)
pData0=np.zeros([npt,6])
pData0[:,[0,1,2,3,5]]=x.reshape([npt,5])
pData0[:,5] = pData0[:,5]/std*Espread

pDataIn = norm2MLI(pData0,sign=1)
np.savetxt('rays.in',pDataIn)

# %% [markdown]
# # Cmds

# %%
raysin  =mli.getElem.raytrace(file1='rays.in',type='readonly')
dump    =mli.getElem.particledump(file='rays.out',precision=15)
track   =mli.getElem.autotrack(type='symplectic',order=5)
fin     =mli.getElem.fin

elemList = elemList + [raysin, dump, track, fin]

# %%
# labor = mli.buildLabor(['iotaline','mapout'])
# mli.writeInputfile(elemList,latticeList,labor)
# mli.run()

# %% [markdown]
# # Lattice

# %%
nlinsert=mli.getElem.nlinsert()

iotaline = latticeList[0]
iotaline.list.insert(0,nlinsert.name)
iotaline.list.append(dump.name)

elemList = elemList + [nlinsert]

# %% [markdown]
# # Labor

# %%
labor = mli.buildLabor(['iotaline','mapout','clear',raysin.name,track.name,str(nturn)+'*'+iotaline.name,'fin'])

# %% [markdown]
# #  Run

# %%
def getTBT(npt,nturn,fname='rays.out'):
    TBT = np.loadtxt(fname)
    print('TBT.shape',TBT.shape)
    TBT = TBT[:npt*nturn,:6]
    out = np.zeros([npt,nturn,6])
    for i in range(nturn):
        out[:,i,:] = TBT[i*npt:(i+1)*npt,:]
        out[:,i,:] = MLI2norm(out[:,i,:])
    return out

# %%
mli.writeInputfile(elemList,latticeList,labor)
mli.run(1)
# !mv mli.log mli.1.log
TBT1 = getTBT(npt,nturn)
print(TBT1.shape)
# !rm rays.out
# Out:
# TBT.shape (131072, 7)
# (64, 2048, 6)

# %% [markdown]
# ### original lattice

# %%
elems,dummy,dummy = mli.readInputfile('mli.in.t3_iota_8_4_t0p4')
# elems[2].driftexact=1
elemList = []
for item in elems:
    if not item.name in ['tasm','aim','vary','anaprint','monitor']:
        elemList.append(item)
elemList = elemList + [raysin, dump, track, nlinsert]

mli.writeInputfile(elemList,latticeList,labor)
mli.run(1)
# !mv mli.log mli.0.log
TBT0 = getTBT(npt,nturn)
print(TBT0.shape)
# !rm rays.out
# Out:
# setarclen is not recognized. skipping...
# autoconcat is not recognized. skipping...
# autoapply is not recognized. skipping...
# reftraj is not recognized. skipping...
# fit is not recognized. skipping...
# bip is not recognized. skipping...
# tip is not recognized. skipping...
# TBT.shape (131072, 7)
# (64, 2048, 6)

# %%
elems,dummy,dummy = mli.readInputfile('mli.in.t3_iota_8_4_t0p4.GlobalDEsext.optimized')
# elems[2].driftexact=1
elemList = []
for item in elems:
    if not item.name in ['tasm','aim','vary','anaprint','monitor']:
        elemList.append(item)
elemList = elemList + [raysin, dump, track, fin, nlinsert]

mli.writeInputfile(elemList,latticeList,labor)
mli.run(1)
# !mv mli.log mli.3.log
TBT3 = getTBT(npt,nturn)
print(TBT3.shape)
# !rm rays.out
# Out:
# TBT.shape (131072, 7)
# (64, 2048, 6)

# %% [markdown]
# ### global opt strength

# %%
import pickle
with open('result.thick.DA.sext','rb') as fp:
    result=pickle.load(fp)
result
# Out:
#      fun: 6.53615095982203
#      jac: array([ 0.00254365,  0.00448885,  0.01040998, -0.00292495,  0.02470779,
#        -0.00434008,  0.00577822, -0.00553309,  0.00559455,  0.01923643,
#         0.01338831, -0.00623013,  0.00419673, -0.00944071, -0.08234533,
#         0.01047091,  0.02148415,  0.01330305])
#  message: 'Optimization terminated successfully.'
#      nit: 18
#  success: True
#        x: array([-156.09747468,  -17.27594582,   49.75982598, -150.2155858 ,
#          48.30684463,    0.76582708, -130.27795607,    3.36513068,
#          53.36842297,   42.95301131,  -57.77981561,  -55.30469806,
#         -65.14724915,   79.40574001,  200.        ,  -89.08757415,
#        -200.        , -164.68229866])

# %%
indexSext = []
SextStrength = []
for i,item in enumerate(elemList):
    try:
        item.elem
        if 'sextupole' == item.elem:
            indexSext.append(i)
            SextStrength.append(item.g2)
            print(item)
    except:
        continue
nSext = len(indexSext)

for i,j in enumerate(indexSext):
    elems[j]['g2']=result.x[i]
# Out:
#  elem: 'sextupole'
#  name: 'sa1r'
#     l: 0.1
#    g2: -150.36690890692725
#
#  elem: 'sextupole'
#  name: 'sc1r'
#     l: 0.1
#    g2: -17.978306652236746
#
#  elem: 'sextupole'
#  name: 'sc2r'
#     l: 0.1
#    g2: 45.19175556303845
#
#  elem: 'sextupole'
#  name: 'sd1r'
#     l: 0.1
#    g2: -127.89554335862469
#
#  elem: 'sextupole'
#  name: 'se1r'
#     l: 0.1
#    g2: 43.1261428206338
#
#  elem: 'sextupole'
#  name: 'se2r'
#     l: 0.1
#    g2: -6.8561300899920425
#
#  elem: 'sextupole'
#  name: 'se2l'
#     l: 0.1
#    g2: -121.83253146307533
#
#  elem: 'sextupole'
#  name: 'se1l'
#     l: 0.1
#    g2: 18.70751813580271
#
#  elem: 'sextupole'
#  name: 'sd1l'
#     l: 0.1
#    g2: 43.21144454808328
#
#  elem: 'sextupole'
#  name: 'sc2l'
#     l: 0.1
#    g2: 42.47319733128577
#
#  elem: 'sextupole'
#  name: 'sc1l'
#     l: 0.1
#    g2: -53.271456501097674
#
#  elem: 'sextupole'
#  name: 'sa1l'
#     l: 0.1
#    g2: -62.7013848638065
#
#  elem: 'sextupole'
#  name: 'sadd1'
#     l: 0.1
#    g2: -67.27681024649665
#
#  elem: 'sextupole'
#  name: 'sadd2'
#     l: 0.1
#    g2: 63.10708297608475
#
#  elem: 'sextupole'
#  name: 'sadd3'
#     l: 0.1
#    g2: 188.62118606585645
#
#  elem: 'sextupole'
#  name: 'sadd4'
#     l: 0.1
#    g2: -119.17756974896334
#
#  elem: 'sextupole'
#  name: 'sadd5'
#     l: 0.1
#    g2: -199.86737780198806
#
#  elem: 'sextupole'
#  name: 'sadd6'
#     l: 0.1
#    g2: -86.06314986827098

# %%
mli.writeInputfile(elemList,latticeList,labor)
mli.run(1)
# !mv mli.log mli.2.log
TBT2 = getTBT(npt,nturn)
print(TBT2.shape)
# !rm rays.out

# %% [markdown]
# ### zero sext strength

# %%
for i,j in enumerate(indexSext):
    elems[j]['g2']=0

# %%
mli.writeInputfile(elemList,latticeList,labor)
mli.run(1)
# !mv mli.log mli.00.log
TBT00 = getTBT(npt,nturn)
print(TBT00.shape)
# !rm rays.out

# %% [markdown]
# # Check invariants

# %%
def getInv(xn,pxn,yn,pyn,delta,tau=NL_t):
    z = xn + 1j*yn
    U = np.real(z/np.sqrt(1-z**2)*np.arcsin(z))
    W = np.real(2*xn/np.sqrt(1-z**2)*np.arcsin(z))
    Hn = 0.5*(xn**2+pxn**2+yn**2+pyn**2)   +tau*U/(1.0+delta)
    In = (xn*pyn -yn*pxn)**2 +xn**2+pxn**2 +tau*W/(1.0+delta)
    return Hn,In

def getInvTBT(TBT):
    npt,nturn,dummy = TBT.shape
    InvTBT = np.zeros([npt,nturn,2])
    for iturn in range(nturn):
        data = TBT[:,iturn,:]
        for ipt in range(npt):
            xn    = data[ipt,0]
            pxn   = data[ipt,1]
            yn    = data[ipt,2]
            pyn   = data[ipt,3]
            delta = data[ipt,5]
            InvTBT[ipt,iturn,:] = getInv(xn,pxn,yn,pyn,delta)
    return InvTBT

# %%
Inv00 = getInvTBT(TBT00)
Inv0 = getInvTBT(TBT0)
Inv1 = getInvTBT(TBT1)
Inv2 = getInvTBT(TBT2)
Inv3 = getInvTBT(TBT3)

# %% [markdown]
# ### Absolute

# %%
print('--max invarinats--')
print(np.max(Inv00[:,:,0]),np.max(Inv00[:,:,1]))
print(np.max(Inv0[:,:,0]),np.max(Inv0[:,:,1]))
print(np.max(Inv1[:,:,0]),np.max(Inv1[:,:,1]))
print(np.max(Inv2[:,:,0]),np.max(Inv2[:,:,1]))
print(np.max(Inv3[:,:,0]),np.max(Inv3[:,:,1]))

# %%
amp0 = np.zeros([npt,2])
amp00 = np.zeros([npt,2])
amp1 = np.zeros([npt,2])
amp2 = np.zeros([npt,2])
amp3 = np.zeros([npt,2])
for i in range(npt):
    amp0[i,0] = np.std(Inv0[i,:,0])
    amp0[i,1] = np.std(Inv0[i,:,1])
    amp00[i,0] = np.std(Inv00[i,:,0])
    amp00[i,1] = np.std(Inv00[i,:,1])
    amp1[i,0] = np.std(Inv1[i,:,0])
    amp1[i,1] = np.std(Inv1[i,:,1])
    amp2[i,0] = np.std(Inv2[i,:,0])
    amp2[i,1] = np.std(Inv2[i,:,1])
    amp3[i,0] = np.std(Inv3[i,:,0])
    amp3[i,1] = np.std(Inv3[i,:,1])
print('--mean of amplitudes--')
print(amp00[:,0].mean(),amp00[:,1].mean())
print(amp0[:,0].mean(),amp0[:,1].mean())
print(amp1[:,0].mean(),amp1[:,1].mean())
print(amp2[:,0].mean(),amp2[:,1].mean())
print(amp3[:,0].mean(),amp3[:,1].mean())

# %%
fig=plt.figure(figsize=(9,4))
plt.subplot(1,2,1)
for i in range(npt):
    plt.plot(Inv00[i,:,0],marker='.',ls='',alpha=0.7)
plt.subplot(1,2,2)
for i in range(npt):
    plt.plot(Inv00[i,:,1],marker='.',ls='',alpha=0.7)
plt.tight_layout()

# %%
fig=plt.figure(figsize=(9,4))
plt.subplot(1,2,1)
for i in range(npt):
    plt.plot(Inv0[i,:,0],marker='.',ls='',alpha=0.7)
plt.subplot(1,2,2)
for i in range(npt):
    plt.plot(Inv0[i,:,1],marker='.',ls='',alpha=0.7)
plt.tight_layout()

# %%
fig=plt.figure(figsize=(9,4))
plt.subplot(1,2,1)
for i in range(npt):
    plt.plot(Inv1[i,:,0],marker='.',ls='',alpha=0.7)
plt.subplot(1,2,2)
for i in range(npt):
    plt.plot(Inv1[i,:,1],marker='.',ls='',alpha=0.7)
plt.tight_layout()

# %%
fig=plt.figure(figsize=(9,4))
plt.subplot(1,2,1)
for i in range(npt):
    plt.plot(Inv2[i,:,0],marker='.',ls='',alpha=0.7)
plt.subplot(1,2,2)
for i in range(npt):
    plt.plot(Inv2[i,:,1],marker='.',ls='',alpha=0.7)
plt.tight_layout()

# %%
fig=plt.figure(figsize=(9,4))
plt.subplot(1,2,1)
for i in range(npt):
    plt.plot(Inv3[i,:,0],marker='.',ls='',alpha=0.7)
plt.subplot(1,2,2)
for i in range(npt):
    plt.plot(Inv3[i,:,1],marker='.',ls='',alpha=0.7)
plt.tight_layout()

# %% [markdown]
# ### Relative

# %%
for i in range(npt):
    Inv00[i,:,0] = Inv00[i,:,0]/Inv00[i,0,0].mean()-1.0
    Inv00[i,:,1] = Inv00[i,:,1]/Inv00[i,0,1].mean()-1.0
    Inv0[i,:,0] = Inv0[i,:,0]/Inv0[i,0,0].mean()-1.0
    Inv0[i,:,1] = Inv0[i,:,1]/Inv0[i,0,1].mean()-1.0
    Inv1[i,:,0] = Inv1[i,:,0]/Inv1[i,0,0].mean()-1.0
    Inv1[i,:,1] = Inv1[i,:,1]/Inv1[i,0,1].mean()-1.0
    Inv2[i,:,0] = Inv2[i,:,0]/Inv2[i,0,0].mean()-1.0
    Inv2[i,:,1] = Inv2[i,:,1]/Inv2[i,0,1].mean()-1.0
    Inv3[i,:,0] = Inv3[i,:,0]/Inv3[i,0,0].mean()-1.0
    Inv3[i,:,1] = Inv3[i,:,1]/Inv3[i,0,1].mean()-1.0

# %%
print('--max invarinats--')
print(np.max(Inv00[:,:,0]),np.max(Inv00[:,:,1]))
print(np.max(Inv0[:,:,0]),np.max(Inv0[:,:,1]))
print(np.max(Inv1[:,:,0]),np.max(Inv1[:,:,1]))
print(np.max(Inv2[:,:,0]),np.max(Inv2[:,:,1]))
print(np.max(Inv3[:,:,0]),np.max(Inv3[:,:,1]))

# %%
amp0 = np.zeros([npt,2])
amp00 = np.zeros([npt,2])
amp1 = np.zeros([npt,2])
amp2 = np.zeros([npt,2])
amp3 = np.zeros([npt,2])
for i in range(npt):
    amp0[i,0] = np.std(Inv0[i,:,0])
    amp0[i,1] = np.std(Inv0[i,:,1])
    amp00[i,0] = np.std(Inv00[i,:,0])
    amp00[i,1] = np.std(Inv00[i,:,1])
    amp1[i,0] = np.std(Inv1[i,:,0])
    amp1[i,1] = np.std(Inv1[i,:,1])
    amp2[i,0] = np.std(Inv2[i,:,0])
    amp2[i,1] = np.std(Inv2[i,:,1])
    amp3[i,0] = np.std(Inv3[i,:,0])
    amp3[i,1] = np.std(Inv3[i,:,1])
print('--mean of amplitudes--')
print(amp00[:,0].mean(),amp00[:,1].mean())
print(amp0[:,0].mean(),amp0[:,1].mean())
print(amp1[:,0].mean(),amp1[:,1].mean())
print(amp2[:,0].mean(),amp2[:,1].mean())
print(amp3[:,0].mean(),amp3[:,1].mean())
# Out:
# --mean of amplitudes--
# 0.0578266343427215 0.07784538850349257
# 0.2274347572471362 0.409685363273802
# 0.0380317258162491 0.07049211606317937
# 0.015267930730867695 0.030339304044930043
# 0.0134799802420844 0.026709776977410383

# %%
fig=plt.figure(figsize=(9,4))
plt.subplot(1,2,1)
for i in range(npt):
    plt.plot(Inv00[i,:,0],marker='.',ls='',alpha=0.7)
plt.subplot(1,2,2)
for i in range(npt):
    plt.plot(Inv00[i,:,1],marker='.',ls='',alpha=0.7)
plt.tight_layout()

# %%
fig=plt.figure(figsize=(9,4))
plt.subplot(1,2,1)
for i in range(npt):
    plt.plot(Inv0[i,:,0],marker='.',ls='',alpha=0.7)
plt.subplot(1,2,2)
for i in range(npt):
    plt.plot(Inv0[i,:,1],marker='.',ls='',alpha=0.7)
plt.tight_layout()

# %%
fig=plt.figure(figsize=(9,4))
plt.subplot(1,2,1)
for i in range(npt):
    plt.plot(Inv1[i,:,0],marker='.',ls='',alpha=0.7)
plt.subplot(1,2,2)
for i in range(npt):
    plt.plot(Inv1[i,:,1],marker='.',ls='',alpha=0.7)
plt.tight_layout()

# %%
fig=plt.figure(figsize=(9,4))
plt.subplot(1,2,1)
for i in range(npt):
    plt.plot(Inv2[i,:,0],marker='.',ls='',alpha=0.7)
plt.subplot(1,2,2)
for i in range(npt):
    plt.plot(Inv2[i,:,1],marker='.',ls='',alpha=0.7)
plt.tight_layout()

# %%
fig=plt.figure(figsize=(9,4))
plt.subplot(1,2,1)
for i in range(npt):
    plt.plot(Inv3[i,:,0],marker='.',ls='',alpha=0.7)
plt.subplot(1,2,2)
for i in range(npt):
    plt.plot(Inv3[i,:,1],marker='.',ls='',alpha=0.7)
plt.tight_layout()

# %%
latticeList[0].list.pop(0)
labor.list =labor.list[:2]
mli.writeInputfile(elemList,latticeList,labor)
mli.run(1)
